# %%
import pandas as pd
df = pd.read_csv("data0.csv", index_col=0).T
df.to_csv('data1.csv')
df.head()
# Out:
# ensemblID  ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  \
# sample_09               90                0              332              728
# sample_16              145                1              344              920
# sample_43              167                2              348              843
# sample_65              187                0              331              739
# sample_07              155                2              394              885
#
# ensemblID  ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036  \
# sample_09              451               32              351              103
# sample_16              497               41              197              155
# sample_43              577               41              225              236
# sample_65              545               46              170              220
# sample_07              411               52              209              370
#
# ...
