# %%
import pandas as pd
import numpy as np

# %%
df_features = pd.read_csv("data1.csv", index_col=0)
df_targets = pd.read_csv("Dignosis.csv", index_col=0)

# %%
df_features.head()
# Out:
#            ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  \
# sample_01              124                2              300              398
# sample_02              111                0              374              351
# sample_03              135                3              265              395
# sample_04              122                1              420              496
# sample_05              209                0              439              917
#
#            ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036  \
# sample_01              421               18               84              206
# sample_02              502               32              278              238
# sample_03              525               28              177              214
# sample_04              365               23              173              243
# sample_05              631               67              428              189
#
#            ENSG00000001084  ENSG00000001167  ...  ENSG00000283690  \
# sample_01             1024              883  ...                0
# sample_02              973             1975  ...                0
# sample_03              990             1580  ...                0
# sample_04             1149              967  ...                0
# sample_05             1161             1368  ...                0
#
#            ENSG00000283691  ENSG00000283692  ENSG00000283693  ENSG00000283694  \
# sample_01                0                2                0                0
# sample_02                0                1                0                0
# sample_03                0                2                0                0
# sample_04                0                4                0                0
# sample_05                0                0                0                0
#
#            ENSG00000283695  ENSG00000283696  ENSG00000283697  ENSG00000283698  \
# sample_01                2               17                0                2
# sample_02                2               13                0                4
# sample_03                1                6                0                1
# sample_04                1               18                0                2
# sample_05                1               31                0                7
#
#            ENSG00000283699
# sample_01                0
# sample_02                0
# sample_03                0
# sample_04                0
# sample_05                0
#
# [5 rows x 58051 columns]

# %%
df_targets.head()
# Out:
#              Disese Group
# Sample Name
# sample_01               0
# sample_02               0
# sample_03               0
# sample_04               0
# sample_05               0

# %%
from sklearn.ensemble import RandomForestClassifier

X = df_features
y = df_targets['Disese Group']

Feature_Names = X.columns


# Set up the Random Forest Classifier
clf = RandomForestClassifier()
clf.fit(X, y)

# Get feature importances
importances = clf.feature_importances_

# Sort features based on their importance scores
sorted_indices = np.argsort(importances)[::-1]

# Select the top-k features with the highest importance scores
k=200
selected_features = Feature_Names[sorted_indices[:k]].tolist()

# Create a new DataFrame with the selected features and target variable
new_df = X[selected_features].copy()
new_df['Disese Group'] = y.values

# Print the new DataFrame
print(new_df.head())
# Out:
#            ENSG00000125107  ENSG00000203280  ENSG00000185015  ENSG00000104368  \
# sample_01             6225                3              206               75
# sample_02             5427                2              358              189
# sample_03             5392                4              331              189
# sample_04             6023                4              268              214
# sample_05             7623                3              345              285
#
#            ENSG00000246366  ENSG00000103489  ENSG00000261460  ENSG00000213058  \
# sample_01                1             2236              829               46
# sample_02               15             3453              945               67
# sample_03               11             2779             1260               47
# sample_04                5             2426              762               22
# sample_05               11             3794             1672               70
#
#            ENSG00000123989  ENSG00000279968  ...  ENSG00000243702  \
# sample_01             1156               23  ...                4
# sample_02             1596               25  ...                4
# sample_03             1389               22  ...                2
# sample_04             1982               20  ...                5
# sample_05             1952               34  ...                8
#
#            ENSG00000267083  ENSG00000224318  ENSG00000177917  ENSG00000221916  \
# sample_01               23                6              325               24
# sample_02               28               12              418               51
# sample_03               20                6              390               32
# sample_04               21                3              312               31
# sample_05               50               15              515               37
#
#            ENSG00000273619  ENSG00000264859  ENSG00000226287  ENSG00000113645  \
# sample_01               71                3               24             1647
# sample_02              111               11               50             2446
# sample_03              123                4               56             1468
# sample_04               66                0               36             1582
# sample_05              109                2               51             2019
#
#            Disese Group
# sample_01             0
# sample_02             0
# sample_03             0
# sample_04             0
# sample_05             0
#
# [5 rows x 201 columns]

# %%
new_df.to_csv("data5.csv")
