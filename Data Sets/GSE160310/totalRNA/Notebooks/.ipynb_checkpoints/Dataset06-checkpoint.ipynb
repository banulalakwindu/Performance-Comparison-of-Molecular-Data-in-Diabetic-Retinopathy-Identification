# %%
import pandas as pd

# %%
df_features = pd.read_csv("C:/Users/ACER/OneDrive - University of Jaffna/UOJ/Education/Research/Data Sets/GSE160310/totalRNA/Notebooks/data1.csv", index_col=0)
df_targets = pd.read_csv("C:/Users/ACER/OneDrive - University of Jaffna/UOJ/Education/Research/Data Sets/GSE160310/totalRNA/Notebooks/Dignosis.csv", index_col=0)

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79 entries, sample_01 to sample_80
# Columns: 58051 entries, ENSG00000000003 to ENSG00000283699
# dtypes: int64(58051)
# memory usage: 35.0+ MB

# %%
df_targets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79 entries, sample_01 to sample_80
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Disese Group  79 non-null     int64
# dtypes: int64(1)
# memory usage: 1.2+ KB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.ensemble import RandomForestClassifier

# Assuming 'df' contains your dataset

X = df_features
y = df_targets['Disese Group']

Feature_Names = X.columns

# Perform feature selection using mutual information with a classifier
# k_values = [10, 15, 25, 50, 100, 150,175,180, 200]  # Number of top features to select
k_values = [49,51,79]
# Create a dictionary to store the selected features for each k value
selected_features_dict = {}

for k in k_values:
    selector = SelectKBest(score_func=mutual_info_classif, k=k)
    X_new = selector.fit_transform(X, y)

    selected_features = [Feature_Names[i]
                         for i in selector.get_support(indices=True)]

    selected_features_dict[k] = selected_features

    # Use a RandomForestClassifier to get feature importances
    clf = RandomForestClassifier(n_estimators=100, random_state=42)
    clf.fit(X_new, y)
    feature_importances = clf.feature_importances_

    # Sort features by importance
    sorted_idx = np.argsort(feature_importances)[::-1]
    # Select the top 100 most important features
    top_features = sorted_idx[:10]

    # Plot feature importances
    plt.figure(figsize=(12, 6))
    plt.title(f"Top {k} Features Importance")
    plt.bar(range(len(top_features)),
            feature_importances[top_features], align="center")
    plt.xticks(range(len(top_features)), [
               selected_features[i] for i in top_features], rotation=90)
    plt.xlabel("Feature")
    plt.ylabel("Importance")
    plt.tight_layout()
    plt.show()

    new_df = pd.DataFrame(X_new, columns=selected_features,
                          index=df_features.index)
    new_df['Diagnosis'] = y.values

    # Save the DataFrame to a CSV file with a custom path and a name indicating the value of k
    file_path = f"C:/Users/ACER/OneDrive - University of Jaffna/UOJ/Education/Research/Data Sets/GSE160310/totalRNA/Feature Selection/Information Gain/data_k_{k}.csv"
    new_df.to_csv(file_path)

# Print the selected features for each k value
for k, features in selected_features_dict.items():
    print(f"Top {k} Features: {features}")

# Print feature importances for the top features
for k in k_values:
    print(f"Top {k} Feature Importances:")
    top_feature_importances = [(selected_features[i], feature_importances[i])
                               for i in sorted_idx[:k]]
    for index, (feature, importance) in enumerate(top_feature_importances, start=1):
        print(f"{index} - {feature}: {importance:.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\ACER\OneDrive - University of Jaffna\UOJ\Education\Research\Data Sets\GSE160310\totalRNA\Notebooks\Dataset06.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/OneDrive%20-%20University%20of%20Jaffna/UOJ/Education/Research/Data%20Sets/GSE160310/totalRNA/Notebooks/Dataset06.ipynb#W4sZmlsZQ%3D%3D?line=19'>20</a> for k in k_values:
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/OneDrive%20-%20University%20of%20Jaffna/UOJ/Education/Research/Data%20Sets/GSE160310/totalRNA/Notebooks/Dataset06.ipynb#W4sZmlsZQ%3D%3D?line=20'>21</a>     selector = SelectKBest(score_func=mutual_info_classif, k=k)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ACER/OneDrive%20-%20University%20of%20Jaffna/UOJ/Education/Research/Data%20Sets/GSE160310/totalRNA/Notebooks/Dataset06.ipynb#W4sZmlsZQ%3D%3D?line=21'>22</a>     X_new = selector.fit_transform(X, y)
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/OneDrive%20-%20University%20of%20Jaffna/UOJ/Education/Research/Data%20Sets/GSE160310/totalRNA/Notebooks/Dataset06.ipynb#W4sZmlsZQ%3D%3D?line=23'>24</a>     selected_features = [Feature_Names[i]
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/OneDrive%20-%20University%20of%20Jaffna/UOJ/Education/Research/Data%20Sets/GSE160310/totalRNA/Notebooks/Dataset06.ipynb#W4sZmlsZQ%3D%3D?line=24'>25</a>                          for i in selector.get_support(indices=True)]
#      <a href='vscode-notebook-cell:/c%3A/Users/ACER/OneDrive%20-%20University%20of%20Jaffna/UOJ/Education/Research/Data%20Sets/GSE160310/totalRNA/Notebooks/Dataset06.ipynb#W4sZmlsZQ%3D%3D?line=26'>27</a>     selected_features_dict[k] = selected_features
#
# File c:\Users\ACER\anaconda3\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File c:\Users\ACER\anaconda3\lib\site-packages\sklearn\base.py:862, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     859     return self.fit(X, **fit_params).transform(X)
#     860 else:
#     861     # fit method of arity 2 (supervised transformation)
# --> 862     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\ACER\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:472, in _BaseFilter.fit(self, X, y)
#     467 X, y = self._validate_data(
#     468     X, y, accept_sparse=["csr", "csc"], multi_output=True
#     469 )
#     471 self._check_params(X, y)
# --> 472 score_func_ret = self.score_func(X, y)
#     473 if isinstance(score_func_ret, (list, tuple)):
#     474     self.scores_, self.pvalues_ = score_func_ret
#
# File c:\Users\ACER\anaconda3\lib\site-packages\sklearn\feature_selection\_mutual_info.py:468, in mutual_info_classif(X, y, discrete_features, n_neighbors, copy, random_state)
#     394 """Estimate mutual information for a discrete target variable.
#     395
#     396 Mutual information (MI) [1]_ between two random variables is a non-negative
#    (...)
#     465        of a Random Vector:, Probl. Peredachi Inf., 23:2 (1987), 9-16
#     466 """
#     467 check_classification_targets(y)
# --> 468 return _estimate_mi(X, y, discrete_features, True, n_neighbors, copy, random_state)
#
# File c:\Users\ACER\anaconda3\lib\site-packages\sklearn\feature_selection\_mutual_info.py:304, in _estimate_mi(X, y, discrete_features, discrete_target, n_neighbors, copy, random_state)
#     297     y = scale(y, with_mean=False)
#     298     y += (
#     299         1e-10
#     300         * np.maximum(1, np.mean(np.abs(y)))
#     301         * rng.standard_normal(size=n_samples)
#     302     )
# --> 304 mi = [
#     305     _compute_mi(x, y, discrete_feature, discrete_target, n_neighbors)
#     306     for x, discrete_feature in zip(_iterate_columns(X), discrete_mask)
#     307 ]
#     309 return np.array(mi)
#
# File c:\Users\ACER\anaconda3\lib\site-packages\sklearn\feature_selection\_mutual_info.py:305, in <listcomp>(.0)
#     297     y = scale(y, with_mean=False)
#     298     y += (
#     299         1e-10
#     300         * np.maximum(1, np.mean(np.abs(y)))
#     301         * rng.standard_normal(size=n_samples)
#     302     )
#     304 mi = [
# --> 305     _compute_mi(x, y, discrete_feature, discrete_target, n_neighbors)
#     306     for x, discrete_feature in zip(_iterate_columns(X), discrete_mask)
#     307 ]
#     309 return np.array(mi)
#
# File c:\Users\ACER\anaconda3\lib\site-packages\sklearn\feature_selection\_mutual_info.py:163, in _compute_mi(x, y, x_discrete, y_discrete, n_neighbors)
#     161     return _compute_mi_cd(y, x, n_neighbors)
#     162 elif not x_discrete and y_discrete:
# --> 163     return _compute_mi_cd(x, y, n_neighbors)
#     164 else:
#     165     return _compute_mi_cc(x, y, n_neighbors)
#
# File c:\Users\ACER\anaconda3\lib\site-packages\sklearn\feature_selection\_mutual_info.py:125, in _compute_mi_cd(c, d, n_neighbors)
#     123 nn.set_params(n_neighbors=k)
#     124 nn.fit(c[mask])
# --> 125 r = nn.kneighbors()[0]
#     126 radius[mask] = np.nextafter(r[:, -1], 0)
#     127 k_all[mask] = k
#
# File c:\Users\ACER\anaconda3\lib\site-packages\sklearn\neighbors\_base.py:891, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     889 if return_distance:
#     890     neigh_dist, neigh_ind = zip(*chunked_results)
# --> 891     results = np.vstack(neigh_dist), np.vstack(neigh_ind)
#     892 else:
#     893     results = np.vstack(chunked_results)
#
# File <__array_function__ internals>:180, in vstack(*args, **kwargs)
#
# File c:\Users\ACER\anaconda3\lib\site-packages\numpy\core\shape_base.py:282, in vstack(tup)
#     280 if not isinstance(arrs, list):
#     281     arrs = [arrs]
# --> 282 return _nx.concatenate(arrs, 0)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:
