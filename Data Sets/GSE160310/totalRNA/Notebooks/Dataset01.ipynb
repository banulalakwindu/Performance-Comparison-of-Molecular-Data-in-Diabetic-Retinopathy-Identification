# %%
import pandas as pd

# Specify the file path to your text file
file_path = r'C:\Users\ACER\OneDrive - University of Jaffna\UOJ\Education\Research\Data Sets\GSE160310\totalRNA\GSE160306_human_retina_DR_totalRNA_counts.txt'

# Initialize empty lists to store data
data = []

# Read the text file line by line
with open(file_path, 'r') as file:
    for line in file:
        # Split each line into values using a comma as the delimiter
        values = line.strip().split(',')
        data.append(values)

# Create a DataFrame from the extracted data
df = pd.DataFrame(data)

# # Set the first row as the column headers
df.columns = df.iloc[0]

# # Drop the first row, which contains the column names
df = df[1:]

# Reset the index
df.reset_index(drop=True, inplace=True)

# Display the DataFrame
df
print(df)

df.to_csv('data0.csv', index=False)
# Out:
# 0            ensemblID sample_09 sample_16 sample_43 sample_65 sample_07  \
# 0      ENSG00000000003        90       145       167       187       155
# 1      ENSG00000000005         0         1         2         0         2
# 2      ENSG00000000419       332       344       348       331       394
# 3      ENSG00000000457       728       920       843       739       885
# 4      ENSG00000000460       451       497       577       545       411
# ...                ...       ...       ...       ...       ...       ...
# 58046  ENSG00000283695         2         3         3         1         0
# 58047  ENSG00000283696        26        19        27        19        26
# 58048  ENSG00000283697         0         0         0         0         0
# 58049  ENSG00000283698         1         0         4         3         4
# 58050  ENSG00000283699         0         0         0         0         0
#
# 0     sample_64 sample_51 sample_19 sample_80  ... sample_18 sample_54  \
# ...

# %%
df = pd.read_csv("data0.csv", index_col=0).T
df.head()
# Out:
# ensemblID  ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  \
# sample_09               90                0              332              728
# sample_16              145                1              344              920
# sample_43              167                2              348              843
# sample_65              187                0              331              739
# sample_07              155                2              394              885
#
# ensemblID  ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036  \
# sample_09              451               32              351              103
# sample_16              497               41              197              155
# sample_43              577               41              225              236
# sample_65              545               46              170              220
# sample_07              411               52              209              370
#
# ...

# %%
df.describe()
# Out:
# ensemblID  ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  \
# count            79.000000        79.000000        79.000000        79.000000
# mean            190.898734         1.481013       346.177215       691.139241
# std             108.009211         1.385463        67.341411       175.547841
# min              90.000000         0.000000       224.000000       351.000000
# 25%             131.000000         0.000000       298.000000       557.000000
# 50%             167.000000         1.000000       339.000000       684.000000
# 75%             211.000000         2.000000       386.000000       801.500000
# max             762.000000         6.000000       555.000000      1119.000000
#
# ensemblID  ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036  \
# count            79.000000        79.000000        79.000000        79.000000
# mean            530.291139        34.860759       184.303797       187.670886
# ...

# %%
df.dtypes
# Out:
# ensemblID
# ENSG00000000003    int64
# ENSG00000000005    int64
# ENSG00000000419    int64
# ENSG00000000457    int64
# ENSG00000000460    int64
#                    ...
# ENSG00000283695    int64
# ENSG00000283696    int64
# ENSG00000283697    int64
# ENSG00000283698    int64
# ENSG00000283699    int64
# Length: 58051, dtype: object

# %%
df = df.sort_index()
df.to_csv('data1.csv')
df
# Out:
# ensemblID  ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  \
# sample_01              124                2              300              398
# sample_02              111                0              374              351
# sample_03              135                3              265              395
# sample_04              122                1              420              496
# sample_05              209                0              439              917
# ...                    ...              ...              ...              ...
# sample_76              235                1              431             1052
# sample_77              188                2              428             1119
# sample_78              347                1              228              554
# sample_79              215                1              291              850
# sample_80              288                1              407              963
#
# ...

# %%
# Get the count of NaN values in each column
nan_counts = df.isnull().sum()

# Sum the NaN counts across all columns
total_nan_count = nan_counts.sum()

# Print the total NaN count
print("Total NaN count:", total_nan_count)
# Out:
# Total NaN count: 0

# %%
# Count the number of features with at least one zero
num_features_with_zeros = (df.iloc[:, 1:] == 0).any().sum()

# Print the count
print(f"Number of features with at least one zero: {num_features_with_zeros}")
# Out:
# Number of features with at least one zero: 34932
