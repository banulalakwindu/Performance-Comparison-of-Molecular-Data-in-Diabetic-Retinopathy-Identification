# %%
import pandas as pd
import numpy as np

# %%
df_features = pd.read_csv("data1.csv", index_col=0)
df_targets = pd.read_csv("Dignosis.csv", index_col=0)

# %%
df_features.head()
# Out:
#            hsa-let-7a-2-3p  hsa-let-7a-3p  hsa-let-7a-5p  hsa-let-7b-3p  \
# sample_01              5.0         958.34     1669011.08         574.75
# sample_02              3.0        1224.84     1113228.84         608.25
# sample_03              3.0        1575.00      548076.06         466.50
# sample_04             10.0        3659.66     1193248.35        1315.50
# sample_05              7.0        2647.16      861134.44        1095.50
#
#            hsa-let-7b-5p  hsa-let-7c-3p  hsa-let-7c-5p  hsa-let-7d-3p  \
# sample_01      452902.16          142.0      203795.00         1128.0
# sample_02      294703.75          107.0      120300.83          513.0
# sample_03      124670.91           79.0       42925.42          688.0
# sample_04      287310.08          204.5       96194.33         1983.5
# sample_05      207922.00          227.0       70847.75         1407.0
#
#            hsa-let-7d-5p  hsa-let-7e-3p  ...  hsa-miR-95-3p  hsa-miR-95-5p  \
# ...

# %%
df_targets.head()
# Out:
#              Disese Group
# Sample Name
# sample_01               0
# sample_02               0
# sample_03               0
# sample_04               0
# sample_05               0

# %%
from sklearn.feature_selection import SelectKBest, chi2

X = df_features
y = df_targets['Disese Group']

Feature_Names = X.columns

# Calculate the chi-square scores between each feature and the target variable
k=200
selector = SelectKBest(score_func=chi2, k=k)
X_new = selector.fit_transform(X, y)

# Print the selected features
selected_feature_indices = selector.get_support(indices=True)
selected_features = Feature_Names[selected_feature_indices]
print("Selected Features:", selected_features)

new_df = pd.DataFrame(X_new, columns=selected_features, index=df_features.index)
new_df['Disese Group'] = y.values

new_df.head(25)
# Out:
# Selected Features: Index(['hsa-let-7a-3p', 'hsa-let-7a-5p', 'hsa-let-7b-5p', 'hsa-let-7c-5p',
#        'hsa-let-7e-5p', 'hsa-let-7f-5p', 'hsa-let-7g-5p', 'hsa-let-7i-5p',
#        'hsa-miR-1', 'hsa-miR-100-5p',
#        ...
#        'hsa-miR-892b', 'hsa-miR-9-3p', 'hsa-miR-9-5p', 'hsa-miR-92a-3p',
#        'hsa-miR-92b-3p', 'hsa-miR-93-5p', 'hsa-miR-95-3p', 'hsa-miR-96-5p',
#        'hsa-miR-98-5p', 'hsa-miR-99a-3p'],
#       dtype='object', length=200)
#            hsa-let-7a-3p  hsa-let-7a-5p  hsa-let-7b-5p  hsa-let-7c-5p  \
# sample_01         958.34     1669011.08      452902.16      203795.00
# sample_02        1224.84     1113228.84      294703.75      120300.83
# sample_03        1575.00      548076.06      124670.91       42925.42
# sample_04        3659.66     1193248.35      287310.08       96194.33
# sample_05        2647.16      861134.44      207922.00       70847.75
# sample_06        4655.50     1259053.95      321917.33      104796.25
# ...

# %%
new_df.to_csv("data4.csv")
