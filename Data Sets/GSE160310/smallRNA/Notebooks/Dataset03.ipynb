# %%
import pandas as pd
import numpy as np

# %%
df_features = pd.read_csv("data1.csv", index_col=0)
df_targets = pd.read_csv("Dignosis.csv", index_col=0)

# %%
df_features.head()
# Out:
#            hsa-let-7a-2-3p  hsa-let-7a-3p  hsa-let-7a-5p  hsa-let-7b-3p  \
# sample_01              5.0         958.34     1669011.08         574.75
# sample_02              3.0        1224.84     1113228.84         608.25
# sample_03              3.0        1575.00      548076.06         466.50
# sample_04             10.0        3659.66     1193248.35        1315.50
# sample_05              7.0        2647.16      861134.44        1095.50
#
#            hsa-let-7b-5p  hsa-let-7c-3p  hsa-let-7c-5p  hsa-let-7d-3p  \
# sample_01      452902.16          142.0      203795.00         1128.0
# sample_02      294703.75          107.0      120300.83          513.0
# sample_03      124670.91           79.0       42925.42          688.0
# sample_04      287310.08          204.5       96194.33         1983.5
# sample_05      207922.00          227.0       70847.75         1407.0
#
#            hsa-let-7d-5p  hsa-let-7e-3p  ...  hsa-miR-95-3p  hsa-miR-95-5p  \
# ...

# %%
df_targets.head()
# Out:
#              Disese Group
# Sample Name
# sample_01               0
# sample_02               0
# sample_03               0
# sample_04               0
# sample_05               0

# %%
X = df_features
y = df_targets['Disese Group']

Feature_Names = X.columns

# Calculate the Pearson correlation coefficient between each feature and the target variable
correlations = X.apply(lambda feature: np.abs(feature.corr(y)))

# Sort the features based on their absolute correlation values
sorted_features = correlations.sort_values(ascending=False)

# Select the top k features with the highest absolute correlation
k = 200  # Number of top features to select
selected_features = sorted_features[:k].index.tolist()

# Create a new DataFrame with the selected features and target variable
new_df = X[selected_features].copy()
new_df.loc[:, 'Disese Group'] = y.values

# Print the new DataFrame
print(new_df.head())
# Out:
#            hsa-miR-585-5p  hsa-miR-148a-3p  hsa-miR-585-3p  hsa-miR-455-3p  \
# sample_01             4.0         23798.50            72.0          232.50
# sample_02             6.0         16331.00           110.0          232.00
# sample_03             9.0         13147.00            41.0           69.00
# sample_04             6.0         28504.33            45.0          247.25
# sample_05            20.0         21093.50           104.0          245.50
#
#            hsa-miR-17-5p  hsa-miR-6513-3p  hsa-miR-2114-3p  hsa-miR-5680  \
# sample_01        1095.33              5.0              1.0          10.0
# sample_02        1702.50              5.0              0.0           6.0
# sample_03         805.50              1.0              0.0           2.0
# sample_04        1600.50              9.0              4.0           8.0
# sample_05        1249.00              8.0              3.0           5.0
#
#            hsa-miR-195-3p  hsa-miR-6861-3p  ...  hsa-miR-939-5p  \
# ...

# %%
new_df.to_csv("data3.csv")
